# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("SalesData.csv")

# %% [markdown]
# #### Apply these steps first :
# - info
# - shape
# - datatypes
# - null values
# - duplicates

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
df.shape
# Out:
# (254, 9)

# %%
df.dtypes
# Out:
# Order ID            int64
# Date               object
# Product            object
# Price             float64
# Quantity          float64
# Purchase Type      object
# Payment Method     object
# Manager            object
# City               object
# dtype: object

# %%
df["Product"].unique()
# Out:
# array(['Fries', 'Beverages', 'Sides & Other', 'Burgers',
#        'Chicken Sandwiches'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Date              0
# Product           0
# Price             0
# Quantity          0
# Purchase Type     0
# Payment Method    0
# Manager           0
# City              0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
df.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
len(df.Manager.unique()[0])
# Out:
# 16

# %%
df["Manager"] = df["Manager"].str.strip().str.replace(r"\s+"," ",regex=True)

# %%
df["Manager"].unique()
# Out:
# array(['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller',
#        'Remy Monet'], dtype=object)

# %% [markdown]
# #### Fixing the datatypes

# %%
df.Quantity = df.Quantity.astype(int)

# %%
df
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49       573       Online
# 1       10453  07-11-2022           Beverages   2.95       745       Online
# 2       10454  07-11-2022       Sides & Other   4.99       200     In-store
# 3       10455  08-11-2022             Burgers  12.99       569     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95       201     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99       200   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99       754   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95       281   Drive-thru
# 252     10712  29-12-2022               Fries   3.49       630   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95       677   Drive-thru
#
#     Payment Method        Manager    City
# 0        Gift Card    Tom Jackson  London
# 1        Gift Card    Pablo Perez  Madrid
# 2        Gift Card     Joao Silva  Lisbon
# 3      Credit Card  Walter Muller  Berlin
# 4      Credit Card  Walter Muller  Berlin
# ..             ...            ...     ...
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin
#
# [254 rows x 9 columns]

# %% [markdown]
# #### Fixing the Date Column.

# %%
df.Date = pd.to_datetime(df.Date,format="mixed")

# %%
df.Date.head(2)
# Out:
# 0   2022-07-11
# 1   2022-07-11
# Name: Date, dtype: datetime64[ns]

# %%
df.Date.dt.month.head(2)
# Out:
# 0    7
# 1    7
# Name: Date, dtype: int32

# %% [markdown]
# #### Most Preferred Payment Method?

# %%
df.sample(3)
# Out:
#      Order ID       Date        Product  Price  Quantity Purchase Type  \
# 217     10677 2022-12-22          Fries   3.49       630     In-store
# 78      10535 2022-11-24        Burgers  12.99       477   Drive-thru
# 47      10504 2022-11-17  Sides & Other   4.99       200   Drive-thru
#
#     Payment Method      Manager    City
# 217           Cash   Joao Silva  Lisbon
# 78     Credit Card  Pablo Perez  Madrid
# 47     Credit Card  Pablo Perez  Madrid

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %% [markdown]
# #### What is the most Selling Product?
# - by Quantity
# - by Revenue

# %%
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Beverages             34938
# Burgers               28996
# Chicken Sandwiches    11132
# Fries                 32016
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
df["Revenue"] = df["Price"] * df["Quantity"]
df.groupby("Product")["Revenue"].sum()
# Out:
# Product
# Beverages             103067.10
# Burgers               376658.04
# Chicken Sandwiches    114602.50
# Fries                 125602.14
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %% [markdown]
# #### Which city had maximum revenue?
# and
# #### Which Manager earned maximum revenue?

# %%
df.groupby("City")["Revenue"].sum()
# Out:
# City
# Berlin    100492.73
# Lisbon    241509.38
# London    211001.83
# Madrid    136098.22
# Paris      79729.62
# Name: Revenue, dtype: float64

# %%
df.groupby("Manager")["Revenue"].sum().reset_index().sort_values(by="Revenue",ascending=False)
# Out:
#          Manager    Revenue
# 0     Joao Silva  241509.38
# 3    Tom Jackson  211001.83
# 1    Pablo Perez  136098.22
# 4  Walter Muller  100492.73
# 2     Remy Monet   79729.62

# %% [markdown]
# #### Average Revenue of November & December?

# %%
df[df["Date"].dt.month==11]["Revenue"].mean()
# Out:
# np.float64(2967.8207216494843)

# %%
df[df["Date"].dt.month==12]["Revenue"].mean()
# Out:
# np.float64(3192.758191489363)

# %% [markdown]
# ### Compare Revenue by Purchase Type.

# %%
df.groupby("Purchase Type")["Revenue"].sum()
# Out:
# Purchase Type
# Drive-thru     178422.12
# In-store       285491.09
# Online         304918.57
# Name: Revenue, dtype: float64

# %% [markdown]
# # HR Analytics

# %%
df = pd.read_csv("HR_Data.csv",encoding="unicode-escape")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490746 entries, 0 to 490745
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          490746 non-null  int64
#  1   Employee_ID         490746 non-null  object
#  2   Full_Name           490746 non-null  object
#  3   Department          490745 non-null  object
#  4   Job_Title           490745 non-null  object
#  5   Hire_Date           490745 non-null  object
#  6   Location            490745 non-null  object
#  7   Performance_Rating  490745 non-null  float64
#  8   Experience_Years    490745 non-null  float64
#  9   Status              490745 non-null  object
#  10  Work_Mode           490745 non-null  object
#  11  Salary_INR          490745 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 44.9+ MB

# %%
df.drop(columns= "Unnamed: 0",inplace=True)

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Full_Name', 'Department', 'Job_Title', 'Hire_Date',
#        'Location', 'Performance_Rating', 'Experience_Years', 'Status',
#        'Work_Mode', 'Salary_INR'],
#       dtype='object')

# %%
df["Hire_Date"]=pd.to_datetime(df["Hire_Date"])

# %%
df["Department"].unique()
# Out:
# array(['IT', 'Marketing', 'HR', 'Operations', 'Finance', 'Sales', 'R&D',
#        nan], dtype=object)

# %%
df["Job_Title"].unique()
# Out:
# array(['Software Engineer', 'SEO Specialist', 'HR Manager',
#        'Logistics Coordinator', 'Finance Manager', 'Account Manager',
#        'Financial Analyst', 'Sales Executive', 'Operations Executive',
#        'HR Executive', 'Sales Director', 'DevOps Engineer',
#        'Content Strategist', 'Marketing Executive', 'Research Scientist',
#        'Accountant', 'IT Manager', 'Supply Chain Manager', 'Data Analyst',
#        'Talent Acquisition Specialist', 'Product Developer',
#        'Operations Director', 'CTO', 'Business Development Manager',
#        'Lab Technician', 'CFO', 'Brand Manager', 'HR Director',
#        'Innovation Manager', nan], dtype=object)

# %%
df["Performance_Rating"].mean().round()
# Out:
# np.float64(3.0)

# %%
import seaborn as sns
sns.countplot(x='Experience_Years',data=df);

# %% [markdown]
# #### What is the distribution of Employee Status (Active,Resigned,Retired,Terminated)?

# %%
status = df["Status"].value_counts()
status.plot(kind="pie",color="mygr",autopct = "%1.1f%%");

# %% [markdown]
# What is the distribution of Work Modes?

# %%
df['Work_Mode'].value_counts().plot(kind='bar');

# %% [markdown]
# #### How many employees are there in each department?

# %%
df["Department"].value_counts()
# Out:
# Department
# IT            147545
# Sales          97928
# Operations     73799
# Marketing      59164
# Finance        48857
# HR             39013
# R&D            24439
# Name: count, dtype: int64

# %% [markdown]
# #### What is the average salary by department?

# %%
df.groupby('Department')['Salary_INR'].mean().astype(int)
# Out:
# Department
# Finance        940804
# HR             741218
# IT            1130413
# Marketing      770094
# Operations     755351
# R&D            799348
# Sales          794072
# Name: Salary_INR, dtype: int64
